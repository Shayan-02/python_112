# %%
from random import choice
from tkinter import filedialog

f = open("test.txt")

person = f.readlines()

print(choice(person))
# Out:
# mohammad

# %%
f2 = open("test.txt", "w")
f2.write("hi")
# Out:
# 2

# %%
f3 = open("test.txt", "a")
f3.write("hi")
# Out:
# 2

# %%
f4 = open("test3.txt", "x")
f4.write("salam")
# Out:
# 5

# %%
f5 = open("download.jpeg", "rb")
print(f5.read())
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x12\x13\x12\x15\x12\x13\x12\x15\x15\x15\x15\x17\x15\x10\x16\x15\x17\x15\x15\x15\x15\x15\x15\x15\x15\x16\x16\x15\x15\x15\x15\x18\x1d( \x18\x1a%\x1d\x15\x15!1!%)+...\x17\x1f383-7(-.+\x01\n\n\n\x0e\r\x0e\x19\x10\x10\x1a- \x1f%---+--+----------------.--+--+------------++---+--\xff\xc0\x00\x11\x08\x01\x13\x00\xb7\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1b\x00\x00\x01\x05\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x00\x02\x04\x05\x06\x01\x07\xff\xc4\x009\x10\x00\x02\x01\x02\x05\x02\x05\x02\x04\x04\x05\x05\x01\x00\x00\x00\x01\x02\x00\x03\x11\x04\x05\x12!1AQ\x06"aq\x81\x13\x912B\xa1\xb1\x14Rr\xc1\x07\x15#\xd1\xf03b\x82\x92\xe1\xb2\xff\xc4\x00\x1a\x01\x00\x02\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x00\x03\x04\x05\x06\xff\xc4\x00+\x11\x00\x02\x02\x01\x04\x01\x03\x03\x04\x03\x01\x00\x00\x00\x00\x00\x00\x01\x02\x11\x03\x04\x12!1A"Qq\x13\x14\xf0a\x91
# ...

# %%
f6 = open("test2.txt", encoding="utf-8")
print(f6.read())
# Out:
# امیر
# رضا
# محمد
# سعید
# وحید
# مجید
# اکبر
# اصغر
# حمید
# آرتین
